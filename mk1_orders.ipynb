# %%
import pandas as pd

# %%
mk1_orders = pd.read_csv(
    r"C:\Users\USER\Data-pipeline-Individual\Market 1 Orders.csv")

# %%
mk1_orders.head()
# Out:
#    Order ID Order Status       Category Name         SKU  Customization Group
# 0  11265015      ORDERED   Cooking Fat & Oil    KKCO0487                  NaN  \
# 1  11264651      ORDERED  Cleaning & Hygiene  KKPT280100                  NaN
# 2  11264651      ORDERED       Flour & Sugar    KKFS0702                  NaN
# 3  11264651      ORDERED    Salt & Seasoning    KKSS0002                  NaN
# 4  11264651      ORDERED           Beverages    KKBE0105                  NaN
#
#    Customization Option  Quantity  Unit Price Cost Price Total Cost Price
# 0                   NaN         1        4400       4250             4250  \
# 1                   NaN         1         180        130              130
# 2                   NaN         6         263        247             1482
# 3                   NaN        10          65         58              580
# 4                   NaN         1         249      208.5            208.5
#
#    ...  Commission Amount  Commission Payout Status  Order Preparation Time
# 0  ...                NaN                       NaN                       0  \
# 1  ...                NaN                       NaN                       0
# 2  ...                NaN                       NaN                       0
# 3  ...                NaN                       NaN                       0
# 4  ...                NaN                       NaN                       0
#
#   Debt Amount Redeemed Loyalty Points Consumed Loyalty Points
# 0           -                      50                       -  \
# 1           -                       -                       -
# 2           -                       -                       -
# 3           -                       -                       -
# 4           -                       -                       -
#
#   Cancellation Reason  Flat Discount Checkout Template Name
# 0                 NaN              0                      -  \
# 1                 NaN              0                      -
# 2                 NaN              0                      -
# 3                 NaN              0                      -
# 4                 NaN              0                      -
#
#   Checkout Template Value
# 0                       -
# 1                       -
# 2                       -
# 3                       -
# 4                       -
#
# [5 rows x 45 columns]

# %%
mk1_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12242 entries, 0 to 12241
# Data columns (total 45 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Order ID                  12242 non-null  int64
#  1   Order Status              12242 non-null  object
#  2   Category Name             12236 non-null  object
#  3   SKU                       12239 non-null  object
#  4   Customization Group       0 non-null      float64
#  5   Customization Option      0 non-null      float64
#  6   Quantity                  12242 non-null  int64
#  7   Unit Price                12242 non-null  int64
#  8   Cost Price                12242 non-null  object
#  9   Total Cost Price          12242 non-null  object
#  10  Total Price               12242 non-null  int64
#  11  Order Total               12242 non-null  float64
#  12  Sub Total                 12242 non-null  int64
#  13  Tax                       12242 non-null  object
#  14  Delivery Charge           12242 non-null  object
#  15  Tip                       12242 non-null  object
#  16  Discount                  12242 non-null  object
#  17  Remaining Balance         12242 non-null  int64
#  18  Payment Method            12242 non-null  object
#  19  Additional Charge         12242 non-null  object
#  20  Taxable Amount            12242 non-null  object
#  21  Transaction ID            12242 non-null  int64
#  22  Currency Symbol           12242 non-null  object
#  23  Transaction Status        0 non-null      float64
#  24  Promo Code                0 non-null      float64
#  25  Customer ID               12242 non-null  int64
#  26  Merchant ID               12242 non-null  int64
#  27  Description               5169 non-null   object
#  28  Distance (in km)          12242 non-null  float64
#  29  Order Time                12242 non-null  object
#  30  Pickup Time               12242 non-null  object
#  31  Delivery Time             12242 non-null  object
#  32  Ratings                   32 non-null     float64
#  33  Reviews                   13 non-null     object
#  34  Merchant Earning          0 non-null      float64
#  35  Commission Amount         0 non-null      float64
#  36  Commission Payout Status  0 non-null      float64
#  37  Order Preparation Time    12242 non-null  int64
#  38  Debt Amount               12242 non-null  object
#  39  Redeemed Loyalty Points   12242 non-null  object
#  40  Consumed Loyalty Points   12242 non-null  object
#  41  Cancellation Reason       0 non-null      float64
#  42  Flat Discount             12242 non-null  int64
#  43  Checkout Template Name    12242 non-null  object
#  44  Checkout Template Value   12242 non-null  object
# dtypes: float64(11), int64(11), object(23)
# memory usage: 4.2+ MB

# %%
mk1_orders.columns
# Out:
# Index(['Order ID', 'Order Status', 'Category Name', 'SKU',
#        'Customization Group', 'Customization Option', 'Quantity', 'Unit Price',
#        'Cost Price', 'Total Cost Price', 'Total Price', 'Order Total',
#        'Sub Total', 'Tax', 'Delivery Charge', 'Tip', 'Discount',
#        'Remaining Balance', 'Payment Method', 'Additional Charge',
#        'Taxable Amount', 'Transaction ID', 'Currency Symbol',
#        'Transaction Status', 'Promo Code', 'Customer ID', 'Merchant ID',
#        'Description', 'Distance (in km)', 'Order Time', 'Pickup Time',
#        'Delivery Time', 'Ratings', 'Reviews', 'Merchant Earning',
#        'Commission Amount', 'Commission Payout Status',
#        'Order Preparation Time', 'Debt Amount', 'Redeemed Loyalty Points',
#        'Consumed Loyalty Points', 'Cancellation Reason', 'Flat Discount',
#        'Checkout Template Name', 'Checkout Template Value'],
#       dtype='object')

# %%
cols_to_drop = ['Customization Group', 'Customization Option', 'Transaction Status', 'Promo Code', 'Ratings', 'Reviews', 'Merchant Earning',
       'Commission Amount', 'Commission Payout Status', 'Cancellation Reason', 'Description']

# %%
mk1_orders = mk1_orders.drop(cols_to_drop, axis=1)

# %%
mk1_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12242 entries, 0 to 12241
# Data columns (total 34 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Order ID                 12242 non-null  int64
#  1   Order Status             12242 non-null  object
#  2   Category Name            12236 non-null  object
#  3   SKU                      12239 non-null  object
#  4   Quantity                 12242 non-null  int64
#  5   Unit Price               12242 non-null  int64
#  6   Cost Price               12242 non-null  object
#  7   Total Cost Price         12242 non-null  object
#  8   Total Price              12242 non-null  int64
#  9   Order Total              12242 non-null  float64
#  10  Sub Total                12242 non-null  int64
#  11  Tax                      12242 non-null  object
#  12  Delivery Charge          12242 non-null  object
#  13  Tip                      12242 non-null  object
#  14  Discount                 12242 non-null  object
#  15  Remaining Balance        12242 non-null  int64
#  16  Payment Method           12242 non-null  object
#  17  Additional Charge        12242 non-null  object
#  18  Taxable Amount           12242 non-null  object
#  19  Transaction ID           12242 non-null  int64
#  20  Currency Symbol          12242 non-null  object
#  21  Customer ID              12242 non-null  int64
#  22  Merchant ID              12242 non-null  int64
#  23  Distance (in km)         12242 non-null  float64
#  24  Order Time               12242 non-null  object
#  25  Pickup Time              12242 non-null  object
#  26  Delivery Time            12242 non-null  object
#  27  Order Preparation Time   12242 non-null  int64
#  28  Debt Amount              12242 non-null  object
#  29  Redeemed Loyalty Points  12242 non-null  object
#  30  Consumed Loyalty Points  12242 non-null  object
#  31  Flat Discount            12242 non-null  int64
#  32  Checkout Template Name   12242 non-null  object
#  33  Checkout Template Value  12242 non-null  object
# dtypes: float64(2), int64(11), object(21)
# memory usage: 3.2+ MB

# %%
mk1_orders = mk1_orders.dropna()

# %%
mk1_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12233 entries, 0 to 12241
# Data columns (total 34 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Order ID                 12233 non-null  int64
#  1   Order Status             12233 non-null  object
#  2   Category Name            12233 non-null  object
#  3   SKU                      12233 non-null  object
#  4   Quantity                 12233 non-null  int64
#  5   Unit Price               12233 non-null  int64
#  6   Cost Price               12233 non-null  object
#  7   Total Cost Price         12233 non-null  object
#  8   Total Price              12233 non-null  int64
#  9   Order Total              12233 non-null  float64
#  10  Sub Total                12233 non-null  int64
#  11  Tax                      12233 non-null  object
#  12  Delivery Charge          12233 non-null  object
#  13  Tip                      12233 non-null  object
#  14  Discount                 12233 non-null  object
#  15  Remaining Balance        12233 non-null  int64
#  16  Payment Method           12233 non-null  object
#  17  Additional Charge        12233 non-null  object
#  18  Taxable Amount           12233 non-null  object
#  19  Transaction ID           12233 non-null  int64
#  20  Currency Symbol          12233 non-null  object
#  21  Customer ID              12233 non-null  int64
#  22  Merchant ID              12233 non-null  int64
#  23  Distance (in km)         12233 non-null  float64
#  24  Order Time               12233 non-null  object
#  25  Pickup Time              12233 non-null  object
#  26  Delivery Time            12233 non-null  object
#  27  Order Preparation Time   12233 non-null  int64
#  28  Debt Amount              12233 non-null  object
#  29  Redeemed Loyalty Points  12233 non-null  object
#  30  Consumed Loyalty Points  12233 non-null  object
#  31  Flat Discount            12233 non-null  int64
#  32  Checkout Template Name   12233 non-null  object
#  33  Checkout Template Value  12233 non-null  object
# dtypes: float64(2), int64(11), object(21)
# memory usage: 3.3+ MB

# %%
mk1_orders.head()
# Out:
#    Order ID Order Status       Category Name         SKU  Quantity
# 0  11265015      ORDERED   Cooking Fat & Oil    KKCO0487         1  \
# 1  11264651      ORDERED  Cleaning & Hygiene  KKPT280100         1
# 2  11264651      ORDERED       Flour & Sugar    KKFS0702         6
# 3  11264651      ORDERED    Salt & Seasoning    KKSS0002        10
# 4  11264651      ORDERED           Beverages    KKBE0105         1
#
#    Unit Price Cost Price Total Cost Price  Total Price  Order Total  ...
# 0        4400       4250             4250         4400       4350.0  ...  \
# 1         180        130              130          180       7255.0  ...
# 2         263        247             1482         1578       7255.0  ...
# 3          65         58              580          650       7255.0  ...
# 4         249      208.5            208.5          249       7255.0  ...
#
#                  Order Time               Pickup Time
# 0  2022-02-17T16:36:27.000Z  2022-02-17T16:37:16.000Z  \
# 1  2022-02-17T16:19:05.000Z  2022-02-17T16:19:53.000Z
# 2  2022-02-17T16:19:05.000Z  2022-02-17T16:19:53.000Z
# 3  2022-02-17T16:19:05.000Z  2022-02-17T16:19:53.000Z
# 4  2022-02-17T16:19:05.000Z  2022-02-17T16:19:53.000Z
#
#               Delivery Time Order Preparation Time Debt Amount
# 0  2022-02-18T08:00:00.000Z                      0           -  \
# 1  2022-02-18T09:00:00.000Z                      0           -
# 2  2022-02-18T09:00:00.000Z                      0           -
# 3  2022-02-18T09:00:00.000Z                      0           -
# 4  2022-02-18T09:00:00.000Z                      0           -
#
#    Redeemed Loyalty Points Consumed Loyalty Points Flat Discount
# 0                       50                       -             0  \
# 1                        -                       -             0
# 2                        -                       -             0
# 3                        -                       -             0
# 4                        -                       -             0
#
#   Checkout Template Name  Checkout Template Value
# 0                      -                        -
# 1                      -                        -
# 2                      -                        -
# 3                      -                        -
# 4                      -                        -
#
# [5 rows x 34 columns]

# %% [markdown]
# after using the set fuction
# set(mk1_orders['column_name]) to check for distinct values as see columns which have no values , columns i can drop are
#
# orders columns from market 1 i can drop are;
# ['Order Preparation Time': 0,'Flat Discount':0,'Checkout Template Name':-, 'Checkout Template Value':-,'Tax':-, 'Delivery Charge':-, 'Tip':-, 'Discount':-,'Remaining Balance':0,'Additional Charge':-, 'Taxable Amount':-, 'Transaction ID':0,  '#Currency Symbol':KSh, Merchant ID:893555]

# %%
mk1_orders.to_csv('up_mk1_orders.csv', index=False)

# %%
df3 = pd.read_csv('up_mk1_orders.csv')
df2 = pd.read_csv('up_mk1_cus.csv')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12233 entries, 0 to 12232
# Data columns (total 34 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Order ID                 12233 non-null  int64
#  1   Order Status             12233 non-null  object
#  2   Category Name            12233 non-null  object
#  3   SKU                      12233 non-null  object
#  4   Quantity                 12233 non-null  int64
#  5   Unit Price               12233 non-null  int64
#  6   Cost Price               12233 non-null  object
#  7   Total Cost Price         12233 non-null  object
#  8   Total Price              12233 non-null  int64
#  9   Order Total              12233 non-null  float64
#  10  Sub Total                12233 non-null  int64
#  11  Tax                      12233 non-null  object
#  12  Delivery Charge          12233 non-null  object
#  13  Tip                      12233 non-null  object
#  14  Discount                 12233 non-null  object
#  15  Remaining Balance        12233 non-null  int64
#  16  Payment Method           12233 non-null  object
#  17  Additional Charge        12233 non-null  object
#  18  Taxable Amount           12233 non-null  object
#  19  Transaction ID           12233 non-null  int64
#  20  Currency Symbol          12233 non-null  object
#  21  Customer ID              12233 non-null  int64
#  22  Merchant ID              12233 non-null  int64
#  23  Distance (in km)         12233 non-null  float64
#  24  Order Time               12233 non-null  object
#  25  Pickup Time              12233 non-null  object
#  26  Delivery Time            12233 non-null  object
#  27  Order Preparation Time   12233 non-null  int64
#  28  Debt Amount              12233 non-null  object
#  29  Redeemed Loyalty Points  12233 non-null  object
#  30  Consumed Loyalty Points  12233 non-null  object
#  31  Flat Discount            12233 non-null  int64
#  32  Checkout Template Name   12233 non-null  object
#  33  Checkout Template Value  12233 non-null  object
# dtypes: float64(2), int64(11), object(21)
# memory usage: 3.2+ MB

# %%
df3.columns = df3.columns.str.strip()
df2.columns = df2.columns.str.strip()

# %%
merged_order1_cus1 = pd.merge(df3, df2, on='Customer ID', how='left')

# %%
merged_order1_cus1
# Out:
#        Order ID Order Status       Category Name         SKU  Quantity
# 0      11265015      ORDERED   Cooking Fat & Oil    KKCO0487         1  \
# 1      11264651      ORDERED  Cleaning & Hygiene  KKPT280100         1
# 2      11264651      ORDERED       Flour & Sugar    KKFS0702         6
# 3      11264651      ORDERED    Salt & Seasoning    KKSS0002        10
# 4      11264651      ORDERED           Beverages    KKBE0105         1
# ...         ...          ...                 ...         ...       ...
# 12228  10387712    COMPLETED       Flour & Sugar    KKFS0702         2
# 12229  10387712    COMPLETED         Meat & Fish    KKMF0100         1
# 12230  10387273    CANCELLED       Flour & Sugar    KKFS0222         3
# 12231  10387273    CANCELLED       Flour & Sugar    KKFSO172         1
# 12232  10387273    CANCELLED    Salt & Seasoning    KKSS1105         4
#
#        Unit Price Cost Price Total Cost Price  Total Price  Order Total  ...
# 0            4400       4250             4250         4400       4350.0  ...  \
# 1             180        130              130          180       7255.0  ...
# 2             263        247             1482         1578       7255.0  ...
# 3              65         58              580          650       7255.0  ...
# 4             249      208.5            208.5          249       7255.0  ...
# ...           ...        ...              ...          ...          ...  ...
# 12228         263        247              494          526       2396.0  ...
# 12229         490        450              450          490       2396.0  ...
# 12230        1670       1630             4890         5010       7180.0  ...
# 12231        1370       1190             1190         1370       7180.0  ...
# 12232         200      187.5              750          800       7180.0  ...
#
#        Consumed Loyalty Points Flat Discount Checkout Template Name
# 0                            -             0                      -  \
# 1                            -             0                      -
# 2                            -             0                      -
# 3                            -             0                      -
# 4                            -             0                      -
# ...                        ...           ...                    ...
# 12228                       26             0                      -
# 12229                       26             0                      -
# 12230                        -             0                      -
# 12231                        -             0                      -
# 12232                        -             0                      -
#
#       Checkout Template Value Last Used Platform  Is Blocked
# 0                           -                WEB           0  \
# 1                           -                WEB           0
# 2                           -                WEB           0
# 3                           -                WEB           0
# 4                           -                WEB           0
# ...                       ...                ...         ...
# 12228                       -                WEB           0
# 12229                       -                WEB           0
# 12230                       -                WEB           0
# 12231                       -                WEB           0
# 12232                       -                WEB           0
#
#                      Created At Language Outstanding Amount  Loyalty Points
# 0      2021-06-11T15:42:57.000Z       en                  0              43
# 1      2021-11-09T15:40:46.000Z       en                  0             145
# 2      2021-11-09T15:40:46.000Z       en                  0             145
# 3      2021-11-09T15:40:46.000Z       en                  0             145
# 4      2021-11-09T15:40:46.000Z       en                  0             145
# ...                         ...      ...                ...             ...
# 12228  2021-09-24T08:52:29.000Z       en                  0            1290
# 12229  2021-09-24T08:52:29.000Z       en                  0            1290
# 12230  2021-07-22T16:47:27.000Z       en                  0            1037
# 12231  2021-07-22T16:47:27.000Z       en                  0            1037
# 12232  2021-07-22T16:47:27.000Z       en                  0            1037
#
# [12233 rows x 40 columns]

# %%
merged_order1_cus1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12233 entries, 0 to 12232
# Data columns (total 40 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Order ID                 12233 non-null  int64
#  1   Order Status             12233 non-null  object
#  2   Category Name            12233 non-null  object
#  3   SKU                      12233 non-null  object
#  4   Quantity                 12233 non-null  int64
#  5   Unit Price               12233 non-null  int64
#  6   Cost Price               12233 non-null  object
#  7   Total Cost Price         12233 non-null  object
#  8   Total Price              12233 non-null  int64
#  9   Order Total              12233 non-null  float64
#  10  Sub Total                12233 non-null  int64
#  11  Tax                      12233 non-null  object
#  12  Delivery Charge          12233 non-null  object
#  13  Tip                      12233 non-null  object
#  14  Discount                 12233 non-null  object
#  15  Remaining Balance        12233 non-null  int64
#  16  Payment Method           12233 non-null  object
#  17  Additional Charge        12233 non-null  object
#  18  Taxable Amount           12233 non-null  object
#  19  Transaction ID           12233 non-null  int64
#  20  Currency Symbol          12233 non-null  object
#  21  Customer ID              12233 non-null  int64
#  22  Merchant ID              12233 non-null  int64
#  23  Distance (in km)         12233 non-null  float64
#  24  Order Time               12233 non-null  object
#  25  Pickup Time              12233 non-null  object
#  26  Delivery Time            12233 non-null  object
#  27  Order Preparation Time   12233 non-null  int64
#  28  Debt Amount              12233 non-null  object
#  29  Redeemed Loyalty Points  12233 non-null  object
#  30  Consumed Loyalty Points  12233 non-null  object
#  31  Flat Discount            12233 non-null  int64
#  32  Checkout Template Name   12233 non-null  object
#  33  Checkout Template Value  12233 non-null  object
#  34  Last Used Platform       12233 non-null  object
#  35  Is Blocked               12233 non-null  int64
#  36  Created At               12233 non-null  object
#  37  Language                 12233 non-null  object
#  38  Outstanding Amount       12233 non-null  int64
#  39  Loyalty Points           12233 non-null  int64
# dtypes: float64(2), int64(14), object(24)
# memory usage: 3.7+ MB

# %%
merged_order1_cus1.to_csv('update_mk1_orders.csv', index=False)

# %%
# Read the orders table
orders = pd.read_csv('update_mk1_orders.csv')

# Calculate aggregate metrics
aggregate_metrics = {
    'Total Transaction Amount per User': orders.groupby('Customer ID')['Order Total'].sum(),
    'Average Order Value': orders['Order Total'].mean(),
    'Total Sales Revenue': orders['Order Total'].sum(),
    'Total Number of Orders': orders['Order ID'].nunique(),
    'Total Number of Customers': orders['Customer ID'].nunique(),
    'Total Quantity Sold per Category': orders.groupby('Category Name')['Quantity'].sum(),
    'Total Revenue per Category': orders.groupby('Category Name')['Order Total'].sum(),
    'Average Transaction Time': (pd.to_datetime(orders['Delivery Time']) - pd.to_datetime(orders['Order Time'])).mean(),
    'Total Revenue per Merchant': orders.groupby('Merchant ID')['Order Total'].sum(),
    'Total Revenue per Payment Method': orders.groupby('Payment Method')['Order Total'].sum()
}

# Display the aggregate metrics
for metric, result in aggregate_metrics.items():
    print(metric)
    print(result)
    print()
# Out:
# Total Transaction Amount per User
# Customer ID
# 3365019     23690.0
# 3365770    238283.0
# 3377953     93840.0
# 3378262    186326.0
# 3385533     74791.0
#              ...
# 5185675      6042.0
# 5188032      6465.0
# 5188161     20190.0
# 5188263     59950.0
# 5189011      4400.0
# Name: Order Total, Length: 550, dtype: float64
#
# Average Order Value
# 10997.868570260769
#
# Total Sales Revenue
# 134536926.22
#
# Total Number of Orders
# 3451
#
# Total Number of Customers
# 550
#
# Total Quantity Sold per Category
# Category Name
# Beverages               456
# Cleaning & Hygiene     2828
# Cooking Fat & Oil      6363
# Flour & Sugar          9460
# Fruits & Vegetables    4045
# Meat & Fish            1605
# Packaging              1548
# Rice & Cereals          827
# Salt & Seasoning       3487
# Spreads                  28
# Name: Quantity, dtype: int64
#
# Total Revenue per Category
# Category Name
# Beverages               2813832.16
# Cleaning & Hygiene      8722558.78
# Cooking Fat & Oil      36259249.42
# Flour & Sugar          38488810.72
# Fruits & Vegetables    12791856.58
# Meat & Fish             4655218.80
# Packaging               6689649.96
# Rice & Cereals          4886585.26
# Salt & Seasoning       18988644.96
# Spreads                  240519.58
# Name: Order Total, dtype: float64
#
# Average Transaction Time
# 0 days 15:12:01.893975312
#
# Total Revenue per Merchant
# Merchant ID
# 893555    1.345369e+08
# Name: Order Total, dtype: float64
#
# Total Revenue per Payment Method
# Payment Method
# CASH         1.198262e+08
# Pay Later    1.471071e+07
# Name: Order Total, dtype: float64

# %%
merged_order1_cus1.columns
# Out:
# Index(['Order ID', 'Order Status', 'Category Name', 'SKU', 'Quantity',
#        'Unit Price', 'Cost Price', 'Total Cost Price', 'Total Price',
#        'Order Total', 'Sub Total', 'Tax', 'Delivery Charge', 'Tip', 'Discount',
#        'Remaining Balance', 'Payment Method', 'Additional Charge',
#        'Taxable Amount', 'Transaction ID', 'Currency Symbol', 'Customer ID',
#        'Merchant ID', 'Distance (in km)', 'Order Time', 'Pickup Time',
#        'Delivery Time', 'Order Preparation Time', 'Debt Amount',
#        'Redeemed Loyalty Points', 'Consumed Loyalty Points', 'Flat Discount',
#        'Checkout Template Name', 'Checkout Template Value',
#        'Last Used Platform', 'Is Blocked', 'Created At', 'Language',
#        'Outstanding Amount', 'Loyalty Points'],
#       dtype='object')

# %%
merged_order1_cus1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12233 entries, 0 to 12232
# Data columns (total 40 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Order ID                 12233 non-null  int64
#  1   Order Status             12233 non-null  object
#  2   Category Name            12233 non-null  object
#  3   SKU                      12233 non-null  object
#  4   Quantity                 12233 non-null  int64
#  5   Unit Price               12233 non-null  int64
#  6   Cost Price               12233 non-null  object
#  7   Total Cost Price         12233 non-null  object
#  8   Total Price              12233 non-null  int64
#  9   Order Total              12233 non-null  float64
#  10  Sub Total                12233 non-null  int64
#  11  Tax                      12233 non-null  object
#  12  Delivery Charge          12233 non-null  object
#  13  Tip                      12233 non-null  object
#  14  Discount                 12233 non-null  object
#  15  Remaining Balance        12233 non-null  int64
#  16  Payment Method           12233 non-null  object
#  17  Additional Charge        12233 non-null  object
#  18  Taxable Amount           12233 non-null  object
#  19  Transaction ID           12233 non-null  int64
#  20  Currency Symbol          12233 non-null  object
#  21  Customer ID              12233 non-null  int64
#  22  Merchant ID              12233 non-null  int64
#  23  Distance (in km)         12233 non-null  float64
#  24  Order Time               12233 non-null  object
#  25  Pickup Time              12233 non-null  object
#  26  Delivery Time            12233 non-null  object
#  27  Order Preparation Time   12233 non-null  int64
#  28  Debt Amount              12233 non-null  object
#  29  Redeemed Loyalty Points  12233 non-null  object
#  30  Consumed Loyalty Points  12233 non-null  object
#  31  Flat Discount            12233 non-null  int64
#  32  Checkout Template Name   12233 non-null  object
#  33  Checkout Template Value  12233 non-null  object
#  34  Last Used Platform       12233 non-null  object
#  35  Is Blocked               12233 non-null  int64
#  36  Created At               12233 non-null  object
#  37  Language                 12233 non-null  object
#  38  Outstanding Amount       12233 non-null  int64
#  39  Loyalty Points           12233 non-null  int64
# dtypes: float64(2), int64(14), object(24)
# memory usage: 3.7+ MB
