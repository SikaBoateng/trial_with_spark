# %%
import pandas as pd

# %%
mk1_del = pd.read_csv(r"C:\Users\USER\Data-pipeline-Individual\Market 1 Deliveries.csv")
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_7812\1372414532.py:1: DtypeWarning: Columns (12,14,16,19,30,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   mk1_del = pd.read_csv(r"C:\Users\USER\Data-pipeline-Individual\Market 1 Deliveries.csv")

# %%
mk1_del.head()
# Out:
#      Task_ID       Order_ID  Relationship     Team_Name Task_Type
# 0  357410575  YR-10691280,0  3.570000e+29  Default Team  Delivery  \
# 1  357410575  YR-10691280,0  3.570000e+29  Default Team  Delivery
# 2  303698961   YR-8221753,0  3.040000e+29  Default Team  Delivery
# 3  302906575   YR-8133470,0  3.030000e+29  Default Team  Delivery
# 4  302906575   YR-8133470,0  3.030000e+29  Default Team  Delivery
#
#                                       Notes
# 0  Deliver tomorrow morning by 8.00a.m note  \
# 1  Deliver tomorrow morning by 8.00a.m note
# 2               To be delivered today by 12
# 3                              DELIVER BY 6
# 4                              DELIVER BY 6
#
#                                             Agent_ID Agent_Name
# 0  potatoes should be Medium large enough for Mak...    1280904  \
# 1  potatoes should be Medium large enough for Mak...    1280904
# 2                                               30pm    1115711
# ...

# %%
mk1_del.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44983 entries, 0 to 44982
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Task_ID                44983 non-null  int64
#  1   Order_ID               44983 non-null  object
#  2   Relationship           44983 non-null  float64
#  3   Team_Name              44983 non-null  object
#  4   Task_Type              44983 non-null  object
#  5   Notes                  13870 non-null  object
#  6   Agent_ID               44983 non-null  object
#  7   Agent_Name             44983 non-null  object
#  8   Distance(m)            44983 non-null  object
#  9   Total_Time_Taken(min)  44983 non-null  object
#  10  Task_Status            44983 non-null  object
#  11  Ref_Images             44983 non-null  object
#  12  Rating                 44983 non-null  object
#  13  Review                 44966 non-null  object
# ...

# %%
mk1_del.columns
# Out:
# Index(['Task_ID', 'Order_ID', 'Relationship', 'Team_Name', 'Task_Type',
#        'Notes', 'Agent_ID', 'Agent_Name', 'Distance(m)',
#        'Total_Time_Taken(min)', 'Task_Status', 'Ref_Images', 'Rating',
#        'Review', 'Latitude', 'Longitude', 'Tags', 'Promo_Applied',
#        'Custom_Template_ID', 'Task_Details_QTY', 'Task_Details_AMOUNT',
#        'Special_Instructions', 'Tip', 'Delivery_Charges', 'Discount',
#        'Subtotal', 'Payment_Type', 'Task_Category', 'Earning', 'Pricing',
#        'Unnamed: 30', 'Unnamed: 31'],
#       dtype='object')

# %%
col_to_drop = ['Notes',"Tags",'Unnamed: 30', 'Unnamed: 31' ]

# %%
mk1_del = mk1_del.drop(col_to_drop, axis = 1)

# %%
mk1_del.head()
# Out:
#      Task_ID       Order_ID  Relationship     Team_Name Task_Type
# 0  357410575  YR-10691280,0  3.570000e+29  Default Team  Delivery  \
# 1  357410575  YR-10691280,0  3.570000e+29  Default Team  Delivery
# 2  303698961   YR-8221753,0  3.040000e+29  Default Team  Delivery
# 3  302906575   YR-8133470,0  3.030000e+29  Default Team  Delivery
# 4  302906575   YR-8133470,0  3.030000e+29  Default Team  Delivery
#
#                                             Agent_ID Agent_Name
# 0  potatoes should be Medium large enough for Mak...    1280904  \
# 1  potatoes should be Medium large enough for Mak...    1280904
# 2                                               30pm    1115711
# 3                                          30 PLEASE          -
# 4                                          30 PLEASE          -
#
#        Distance(m) Total_Time_Taken(min)           Task_Status  ...
# 0  Malombe Kimathi                     -  18 Jan 2022 07:59:25  ...  \
# ...

# %%
mk1_del.isnull().sum()
# Out:
# Task_ID                    0
# Order_ID                   0
# Relationship               0
# Team_Name                  0
# Task_Type                  0
# Agent_ID                   0
# Agent_Name                 0
# Distance(m)                0
# Total_Time_Taken(min)      0
# Task_Status                0
# Ref_Images                 0
# Rating                     0
# Review                    17
# Latitude                   0
# Longitude                  0
# Promo_Applied            109
# Custom_Template_ID         0
# Task_Details_QTY           0
# Task_Details_AMOUNT        0
# Special_Instructions       1
# Tip                        0
# Delivery_Charges           0
# Discount                   0
# Subtotal                   0
# Payment_Type               0
# Task_Category              0
# Earning                    0
# Pricing                    0
# dtype: int64

# %%
mk1_del = mk1_del.dropna()

# %%
mk1_del.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44856 entries, 109 to 44982
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Task_ID                44856 non-null  int64
#  1   Order_ID               44856 non-null  object
#  2   Relationship           44856 non-null  float64
#  3   Team_Name              44856 non-null  object
#  4   Task_Type              44856 non-null  object
#  5   Agent_ID               44856 non-null  object
#  6   Agent_Name             44856 non-null  object
#  7   Distance(m)            44856 non-null  object
#  8   Total_Time_Taken(min)  44856 non-null  object
#  9   Task_Status            44856 non-null  object
#  10  Ref_Images             44856 non-null  object
#  11  Rating                 44856 non-null  object
#  12  Review                 44856 non-null  object
#  13  Latitude               44856 non-null  object
# ...

# %%
mk1_del.to_csv('up_mk1_del.csv', index=False)

# %%
df1 = pd.read_csv('up_mk1_del.csv')
df2 = pd.read_csv('up_mk1_cus.csv')
df6 = pd.read_csv('up_mk1_orders.csv', usecols = ['Order ID', 'Customer ID'])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_7812\3203423425.py:1: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('up_mk1_del.csv')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44856 entries, 0 to 44855
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Task_ID                44856 non-null  int64
#  1   Order_ID               44856 non-null  object
#  2   Relationship           44856 non-null  float64
#  3   Team_Name              44856 non-null  object
#  4   Task_Type              44856 non-null  object
#  5   Agent_ID               44856 non-null  object
#  6   Agent_Name             44856 non-null  object
#  7   Distance(m)            44856 non-null  object
#  8   Total_Time_Taken(min)  44856 non-null  object
#  9   Task_Status            44856 non-null  object
#  10  Ref_Images             44856 non-null  object
#  11  Rating                 44856 non-null  int64
#  12  Review                 44856 non-null  object
#  13  Latitude               44856 non-null  float64
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         4177 non-null   int64
#  1   Last Used Platform  4177 non-null   object
#  2   Is Blocked          4177 non-null   int64
#  3   Created At          4177 non-null   object
#  4   Language            4177 non-null   object
#  5   Outstanding Amount  4177 non-null   int64
#  6   Loyalty Points      4177 non-null   int64
# dtypes: int64(4), object(3)
# memory usage: 228.6+ KB

# %% [markdown]
# after performing set method on the columns , columns i can drop are Team_Name with value "Default Team" and Pricing with values "-" or "0"

# %%
merged_ord1_cus1 = pd.merge(df6, df2, on='Customer ID', how='inner')

# %%
merged_ord1_cus1
# Out:
#        Order ID  Customer ID Last Used Platform  Is Blocked
# 0      11265015      3755460                WEB           0  \
# 1      11213888      3755460                WEB           0
# 2      10606303      3755460                WEB           0
# 3      10606303      3755460                WEB           0
# 4      11264651      4541187                WEB           0
# ...         ...          ...                ...         ...
# 12228  10414449      4006884                WEB           0
# 12229  10413672      4021765                WEB           0
# 12230  10413672      4021765                WEB           0
# 12231  10413630      4021765                WEB           0
# 12232  10413630      4021765                WEB           0
#
#                      Created At Language  Outstanding Amount  Loyalty Points
# 0      2021-06-11T15:42:57.000Z       en                   0              43
# 1      2021-06-11T15:42:57.000Z       en                   0              43
# ...

# %%
merged_ord1_cus1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12233 entries, 0 to 12232
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Order ID            12233 non-null  int64
#  1   Customer ID         12233 non-null  int64
#  2   Last Used Platform  12233 non-null  object
#  3   Is Blocked          12233 non-null  int64
#  4   Created At          12233 non-null  object
#  5   Language            12233 non-null  object
#  6   Outstanding Amount  12233 non-null  int64
#  7   Loyalty Points      12233 non-null  int64
# dtypes: int64(5), object(3)
# memory usage: 764.7+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44856 entries, 0 to 44855
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Task_ID                44856 non-null  int64
#  1   Order_ID               44856 non-null  object
#  2   Relationship           44856 non-null  float64
#  3   Team_Name              44856 non-null  object
#  4   Task_Type              44856 non-null  object
#  5   Agent_ID               44856 non-null  object
#  6   Agent_Name             44856 non-null  object
#  7   Distance(m)            44856 non-null  object
#  8   Total_Time_Taken(min)  44856 non-null  object
#  9   Task_Status            44856 non-null  object
#  10  Ref_Images             44856 non-null  object
#  11  Rating                 44856 non-null  int64
#  12  Review                 44856 non-null  object
#  13  Latitude               44856 non-null  float64
# ...

# %%
df1.rename(columns = {'Order_ID': 'Order ID'}, inplace = True)

# %%
# Convert 'Order ID' column to string type in merged_ord1_cus1 DataFrame
merged_ord1_cus1['Order ID'] = merged_ord1_cus1['Order ID'].astype(str)

# %%
merged_ord1_cus1.columns = merged_ord1_cus1.columns.str.strip()
df1.columns = df1.columns.str.strip()

# %%
# Extract numerical part from Order IDs in the second DataFrame
df1['Order ID'] = df1['Order ID'].str.extract('(\d+)')

# %%
df1
# Out:
#          Task_ID Order ID  Relationship     Team_Name Task_Type Agent_ID
# 0      242338320      NaN  2.420000e+29  Default Team   Pick-up  1001204  \
# 1      338884973  9890304  3.390000e+29  Default Team  Delivery  1170096
# 2      338884973  9890304  3.390000e+29  Default Team  Delivery  1170096
# 3      338882549  9890225  3.390000e+29  Default Team  Delivery  1170096
# 4      338882549  9890225  3.390000e+29  Default Team  Delivery  1170096
# ...          ...      ...           ...           ...       ...      ...
# 44851  338907538  9891023  3.390000e+29  Default Team  Delivery        -
# 44852  338902457  9890869  3.390000e+29  Default Team  Delivery  1051943
# 44853  338902457  9890869  3.390000e+29  Default Team  Delivery  1051943
# 44854  338902457  9890869  3.390000e+29  Default Team  Delivery  1051943
# 44855  338902457  9890869  3.390000e+29  Default Team  Delivery  1051943
#
#           Agent_Name Distance(m) Total_Time_Taken(min) Task_Status  ...
# ...

# %%
df1 = df1.dropna(axis =0)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44855 entries, 1 to 44855
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Task_ID                44855 non-null  int64
#  1   Order ID               44855 non-null  object
#  2   Relationship           44855 non-null  float64
#  3   Team_Name              44855 non-null  object
#  4   Task_Type              44855 non-null  object
#  5   Agent_ID               44855 non-null  object
#  6   Agent_Name             44855 non-null  object
#  7   Distance(m)            44855 non-null  object
#  8   Total_Time_Taken(min)  44855 non-null  object
#  9   Task_Status            44855 non-null  object
#  10  Ref_Images             44855 non-null  object
#  11  Rating                 44855 non-null  int64
#  12  Review                 44855 non-null  object
#  13  Latitude               44855 non-null  float64
# ...

# %%
merged_del1_cus1 = pd.merge(df1, merged_ord1_cus1, on='Order ID', how='inner')

# %%
merged_del1_cus1.head()
# Out:
#      Task_ID  Order ID  Relationship     Team_Name Task_Type Agent_ID
# 0  368105817  11265015  3.680000e+29  Default Team  Delivery        -  \
# 1  368098308  11264651  3.680000e+29  Default Team  Delivery        -
# 2  368098308  11264651  3.680000e+29  Default Team  Delivery        -
# 3  368098308  11264651  3.680000e+29  Default Team  Delivery        -
# 4  368098308  11264651  3.680000e+29  Default Team  Delivery        -
#
#   Agent_Name Distance(m) Total_Time_Taken(min) Task_Status  ... Task_Category
# 0          -           -                     -  Unassigned  ...             -  \
# 1          -           -                     -  Unassigned  ...             -
# 2          -           -                     -  Unassigned  ...             -
# 3          -           -                     -  Unassigned  ...             -
# 4          -           -                     -  Unassigned  ...             -
#
#    Earning Pricing  Customer ID  Last Used Platform Is Blocked
# ...

# %%
merged_del1_cus1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64848 entries, 0 to 64847
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Task_ID                64848 non-null  int64
#  1   Order ID               64848 non-null  object
#  2   Relationship           64848 non-null  float64
#  3   Team_Name              64848 non-null  object
#  4   Task_Type              64848 non-null  object
#  5   Agent_ID               64848 non-null  object
#  6   Agent_Name             64848 non-null  object
#  7   Distance(m)            64848 non-null  object
#  8   Total_Time_Taken(min)  64848 non-null  object
#  9   Task_Status            64848 non-null  object
#  10  Ref_Images             64848 non-null  object
#  11  Rating                 64848 non-null  int64
#  12  Review                 64848 non-null  object
#  13  Latitude               64848 non-null  float64
# ...

# %%
set(merged_del1_cus1['Customer ID'])
# Out:
# {3365019,
#  3365770,
#  3377953,
#  3378262,
#  3385533,
#  3411830,
#  3417088,
#  3457559,
#  3472118,
#  3519514,
#  3553157,
#  3554524,
#  3555286,
#  3636098,
#  3647723,
#  3648386,
#  3648474,
#  3648607,
#  3653840,
#  3664740,
#  3669648,
#  3671732,
#  3673520,
#  3676428,
#  3690101,
#  3700182,
#  3707892,
#  3708566,
#  3714151,
#  3715164,
#  3715510,
#  3715544,
#  3730896,
#  3731925,
#  3732410,
#  3736578,
#  3741824,
#  3741882,
#  3741931,
#  3749729,
#  3749893,
#  3754477,
#  3755460,
#  3756514,
#  3758306,
#  3758785,
#  3759058,
#  3761185,
#  3761457,
#  3761507,
#  3766123,
#  3771529,
#  3772578,
#  3793841,
#  3811665,
#  3812129,
#  3813302,
#  3815751,
#  3822089,
#  3822205,
#  3823450,
#  3825529,
#  3826113,
#  3827014,
#  3827726,
#  3850370,
#  3857710,
#  3858524,
#  3860809,
#  3860942,
#  3866034,
#  3869073,
#  3870786,
#  3874460,
#  3874463,
#  3874884,
#  3876525,
#  3880473,
#  3891722,
#  3892184,
#  3893187,
#  3896139,
#  3897364,
# ...

# %%
merged_del1_cus1.columns
# Out:
# Index(['Task_ID', 'Order ID', 'Relationship', 'Team_Name', 'Task_Type',
#        'Agent_ID', 'Agent_Name', 'Distance(m)', 'Total_Time_Taken(min)',
#        'Task_Status', 'Ref_Images', 'Rating', 'Review', 'Latitude',
#        'Longitude', 'Promo_Applied', 'Custom_Template_ID', 'Task_Details_QTY',
#        'Task_Details_AMOUNT', 'Special_Instructions', 'Tip',
#        'Delivery_Charges', 'Discount', 'Subtotal', 'Payment_Type',
#        'Task_Category', 'Earning', 'Pricing', 'Customer ID',
#        'Last Used Platform', 'Is Blocked', 'Created At', 'Language',
#        'Outstanding Amount', 'Loyalty Points'],
#       dtype='object')

# %%
merged_del1_cus1.to_csv('update_mk1_del.csv', index=False)

# %%
merged_del1_cus1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64848 entries, 0 to 64847
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Task_ID                64848 non-null  int64
#  1   Order ID               64848 non-null  object
#  2   Relationship           64848 non-null  float64
#  3   Team_Name              64848 non-null  object
#  4   Task_Type              64848 non-null  object
#  5   Agent_ID               64848 non-null  object
#  6   Agent_Name             64848 non-null  object
#  7   Distance(m)            64848 non-null  object
#  8   Total_Time_Taken(min)  64848 non-null  object
#  9   Task_Status            64848 non-null  object
#  10  Ref_Images             64848 non-null  object
#  11  Rating                 64848 non-null  int64
#  12  Review                 64848 non-null  object
#  13  Latitude               64848 non-null  float64
# ...

# %% [markdown]
# Ill later update the csvs and remove some more columns
